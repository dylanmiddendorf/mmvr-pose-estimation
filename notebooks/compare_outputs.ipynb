# %%
import numpy as np
import matplotlib.pyplot as plt

outputs = np.load("../sample-output.npz")
guess, truth = outputs["guess"], outputs["truth"]
guess: np.ndarray
print(guess.shape)

for i in range(6, 10):
    fig = plt.figure()
    ax= fig.add_subplot(1,2,1)
    ax.imshow(guess[2][i])
    ax= fig.add_subplot(1,2,2)
    ax.imshow(truth[2][i])
    plt.show()
# Out:
# (16, 17, 48, 64)
